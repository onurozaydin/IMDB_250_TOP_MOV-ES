# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("ımdb_top_250_movies.csv")

# %%
data.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
data.describe()
# Out:
#              rank         year      rating
# count  250.000000   250.000000  250.000000
# mean   125.500000  1986.360000    8.307200
# std     72.312977    25.125356    0.229081
# min      1.000000  1921.000000    8.000000
# 25%     63.250000  1966.250000    8.100000
# 50%    125.500000  1994.000000    8.200000
# 75%    187.750000  2006.000000    8.400000
# max    250.000000  2022.000000    9.300000

# %%
plt.figure(figsize=(10, 6))
plt.title("Türlerin Dağılımı")
data["genre"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title("Yıllara Göre Film Sayısı")
sns.lineplot(data=data, x="year", y="name", ci=None)
plt.show()
# Out:
# C:\Users\ONUR\AppData\Local\Temp\ipykernel_15424\3091495141.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=data, x="year", y="name", ci=None)

# %%
plt.figure(figsize=(10, 6))
plt.title("Bütçe ve Gişe Hasılatı Arasındaki İlişki")
sns.scatterplot(data=data, x="budget", y="box_office")
plt.show()

# %%
top10 = data.sort_values(by="rating", ascending=False).head(10)

# %%
plt.figure(figsize=(10, 6))
plt.title("En İyi 10 Filmin Türlerin Dağılımı")
top10["genre"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title("En İyi 10 Filmin Yıllara Göre Oranı")
total_movies_per_year = data["year"].value_counts()
top10_movies_per_year = top10["year"].value_counts()
ratio = top10_movies_per_year / total_movies_per_year * 100
sns.lineplot(data=ratio, ci=None)
plt.show()
# Out:
# C:\Users\ONUR\AppData\Local\Temp\ipykernel_15424\3605071669.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=ratio, ci=None)

# %%
plt.figure(figsize=(10, 6))
plt.title("En İyi 10 Filmin Bütçesi ve Gişe Hasılatı Arasındaki İlişki")
sns.scatterplot(data=top10, x="budget", y="box_office")
plt.show()
